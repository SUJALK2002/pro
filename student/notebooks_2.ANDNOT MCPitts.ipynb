# %%
# Activation Function
def activate(net, theta):
    if net >= theta:
        return 1
    else:
        return 0

# Input combinations
inputs = [(0,0), (0,1), (1,0), (1,1)]

# Weights array
w = [1, -1]

# Threshold
theta = 1

print("x1 x2 Output")

for x1, x2 in inputs:

    # Calculate net input
    net = x1*w[0] + x2*w[1]

    # Get output
    y = activate(net, theta)

    print(x1," ", x2, " ", y)
# Input:
# Input combinations are (0,0), (0,1), (1,0), and (1,1). These are binary input values given to the perceptron model for checking activation function output.
# Output:
# Program prints output values either 0 or 1 for every input combination based on weighted sum and threshold comparison using activation function.
# def activate(net, theta):
# Defines a function named activate. This function takes net input and threshold value as parameters and returns output based on condition checking.
# if net >= theta:
# Checks whether calculated net input is greater than or equal to threshold value. If condition becomes true output neuron gets activated.
# return 1
# Returns output value 1 when net input is greater than or equal to threshold. It represents activated state of perceptron neuron.
# else:
# Executes when condition in if statement becomes false.
# return 0
# Returns output value 0 when net input is less than threshold. It represents inactive state of perceptron neuron.
# inputs = [(0,0), (0,1), (1,0), (1,1)]
# Stores all possible binary input combinations in list form. These combinations are used to test perceptron model for different input conditions.
# w = [1, -1]
# Defines weights for input values. First input has weight 1 and second input has weight -1 which affects net calculation.
# theta = 1
# Defines threshold value for activation function. Output becomes 1 only when net input is greater than or equal to this threshold.
# print("x1 x2 Output")
# Prints heading for output table showing input values and corresponding output values.
# for x1, x2 in inputs:
# Starts loop for accessing every input pair one by one from input list. x1 stores first value and x2 stores second value.
# net = x1*w[0] + x2*w[1]
# Calculates net input by multiplying input values with their corresponding weights and then adding the results together.
# y = activate(net, theta)
# Calls activation function using calculated net value and threshold. Returned value is stored in variable y.
# print(x1," ", x2, " ", y)
# Prints input values and corresponding output value generated by activation function.
# Logic Of Program:
# Step 1: Define activation function using threshold logic.
# Step 2: Store all binary input combinations in list.
# Step 3: Assign weights to input values.
# Step 4: Set threshold value for neuron activation.
# Step 5: Calculate weighted sum called net input.
# Step 6: Compare net input with threshold using activation function.
# Step 7: Print output for every input combination.
# Working Of Program:
# For input (0,0):
# Net = 0*1 + 0*(-1) = 0
# Since 0 is less than threshold 1, output becomes 0.
# For input (0,1):
# Net = 0*1 + 1*(-1) = -1
# Since -1 is less than threshold 1, output becomes 0.
# For input (1,0):
# Net = 1*1 + 0*(-1) = 1
# Since 1 is equal to threshold 1, output becomes 1.
# For input (1,1):
# Net = 1*1 + 1*(-1) = 0
# Since 0 is less than threshold 1, output becomes 0.
# Final Output Table:
# x1 x2 Output
# 0  0   0
# 0  1   0
# 1  0   1
# 1  1   0
# Viva Questions And Answers:
# Q1. What is perceptron in Artificial Neural Network?
# Ans: Perceptron is the simplest type of artificial neural network model. It consists of inputs, weights, activation function and output. It is mainly used for solving simple binary classification problems.
# Q2. What is activation function in perceptron?
# Ans: Activation function decides whether neuron should produce output or not based on calculated net input value. It introduces decision making capability into the neural network model.
# Q3. What is threshold value in perceptron?
# Ans: Threshold value is a fixed limit used in activation function. If calculated net input becomes greater than or equal to threshold then neuron becomes activated and produces output 1.
# Q4. What is weighted sum or net input?
# Ans: Weighted sum is calculated by multiplying input values with corresponding weights and then adding all results together. This value is passed to activation function for output generation.
# Q5. What are weights in neural networks?
# Ans: Weights are numerical values assigned to inputs in neural networks. They control importance of each input and directly affect output produced by perceptron model.
# Q6. Why are weights important in ANN?
# Ans: Weights are important because they help neural networks learn patterns from data. Proper weight values improve prediction accuracy and overall performance of neural network model.
# Q7. What type of activation function is used in this program?
# Ans: This program uses binary step activation function. It gives output either 0 or 1 depending on whether net input crosses threshold value or not.
# Q8. What is binary classification?
# Ans: Binary classification is a machine learning task where output belongs to only two classes such as yes or no, true or false, or 0 and 1.
# Q9. Why does perceptron give only binary output?
# Ans: Perceptron mainly uses binary step activation function which produces only two output states. Because of this it is suitable for binary classification tasks only.
# Q10. What is purpose of activation function in ANN?
# Ans: Activation function helps neural networks learn complex relationships by introducing non-linearity and deciding whether neuron should activate based on calculated net input value.
# Q11. What is role of threshold in activation function?
# Ans: Threshold acts like decision boundary. If net input crosses threshold neuron activates otherwise it remains inactive. This helps neural network make classification decisions correctly.
# Q12. What is use of loop in this program?
# Ans: Loop is used to process all input combinations one by one automatically instead of writing separate statements for every input pair manually.
# Q13. Why is tuple used for inputs?
# Ans: Tuple is used because it stores input pairs together in fixed form. It helps organize multiple binary input combinations clearly and efficiently inside list.
# Q14. What is function in Python?
# Ans: Function is reusable block of code used for performing specific task. It improves readability, reduces repetition and makes programs easier to understand and maintain.
# Q15. What is meaning of return statement?
# Ans: Return statement sends output value back from function to function call location. In this program it returns either 0 or 1 from activation function.
# Q16. What is ANN?
# Ans: Artificial Neural Network is a computational model inspired by human brain neurons. It processes input data, learns patterns and generates predictions or classifications automatically.
# Q17. What is neuron in ANN?
# Ans: Neuron is basic processing unit of artificial neural network. It receives inputs, performs calculations using weights and activation function, then produces output value.
# Q18. What is logical operation in perceptron?
# Ans: Logical operation means performing binary decision tasks such as AND, OR and NOT using perceptron model with proper weights and threshold values.
# Q19. Which logical gate behavior is shown in this program?
# Ans: This program behaves similar to logical operation where output becomes 1 only when first input is active and second input does not affect positively due to negative weight.
# Q20. What are advantages of perceptron model?
# Ans: Perceptron model is simple, easy to implement, fast for basic classification tasks and useful for understanding fundamental concepts of artificial neural networks and machine learning.
# Out:
# x1 x2 Output
# 0   0   0
# 0   1   0
# 1   0   1
# 1   1   0

# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %% [markdown]
# ## Next steps 🏃
#
# This is just a short introduction to JupyterLab and Jupyter Notebooks. See below for some more ways to interact with tools in the Jupyter ecosystem, and its community.
#
# ### Other notebooks in this demo
#
# Here are some other notebooks in this demo. Each of the items below corresponds to a file or folder in the **file browser to the left**.
#
# - [**`Lorenz.ipynb`**](Lorenz.ipynb) uses Python to demonstrate interactive visualizations and computations around the [Lorenz system](https://en.wikipedia.org/wiki/Lorenz_system). It shows off basic Python functionality, including more visualizations, data structures, and scientific computing libraries.
# - [**`r.ipynb`**](r.ipynb) demonstrates the R programming language for statistical computing and data analysis.
# - [**`cpp.ipynb`**](cpp.ipynb) demonstrates the C++ programming language for scientific computing and data analysis.
# - [**`sqlite.ipynb`**](sqlite.ipynb) demonstrates how an in-browser sqlite kernel to run your own SQL commands from the notebook. It uses the [jupyterlite/xeus-sqlite-kernel](https://github.com/jupyterlite/xeus-sqlite-kernel).
#
# ### Other sources of information in Jupyter
#
# - **More on using JupyterLab**: See [the JupyterLab documentation](https://jupyterlab.readthedocs.io/en/stable/) for more thorough information about how to install and use JupyterLab.
# - **More interactive demos**: See [try.jupyter.org](https://try.jupyter.org) for more interactive demos with the Jupyter ecosystem.
# - **Learn more about Jupyter**: See [the Jupyter community documentation](https://docs.jupyter.org) to learn more about the project, its community and tools, and how to get involved.
# - **Join our discussions**: The [Jupyter Community Forum](https://discourse.jupyter.org) is a place where many in the Jupyter community ask questions, help one another, and discuss issues around interactive computing and our ecosystem.
